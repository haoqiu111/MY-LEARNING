# %%
import os
# %cd /home/xiaoguo/anaconda3/envs/mmgen/mmgeneration/
# Out:
# /home/xiaoguo/anaconda3/envs/mmgen/mmgeneration

# %%
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/cyclegan_lsgan_resnet_in_facades_b1x1_80k_vangogh2photo.py -O configs/cyclegan/cyclegan_lsgan_resnet_in_facades_b1x1_80k_vangogh2photo.py

# %%
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/config/cyclegan_lsgan_resnet_in_facades_b1x1_80k_cezanne2photo.py -O configs/cyclegan/cyclegan_lsgan_resnet_in_facades_b1x1_80k_cezanne2photo.py
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/config/cyclegan_lsgan_resnet_in_facades_b1x1_80k_ukiyoe2photo.py -O configs/cyclegan/cyclegan_lsgan_resnet_in_facades_b1x1_80k_ukiyoe2photo.py
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/config/cyclegan_lsgan_resnet_in_facades_b1x1_80k_monet2photo.py -O configs/cyclegan/cyclegan_lsgan_resnet_in_facades_b1x1_80k_monet2photo.py

# %%
# !python tools/train.py configs/cyclegan/cyclegan_lsgan_resnet_in_facades_b1x1_80k_city2bdd2.py --work-dir work_dirs/experiments/cyclegan_city2bdd2/
# Out:
# /home/xiaoguo/anaconda3/envs/mmgen/lib/python3.8/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# tools/train.py:97: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# tools/train.py:107: UserWarning: Setting MKL_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# 2023-06-09 23:52:02,368 - mmgen - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.16 (default, Mar  2 2023, 03:21:46) [GCC 11.2.0]
# CUDA available: True
# CUDA_HOME: /home/xiaoguo/anaconda3/envs/mmgen
# NVCC: Build cuda_11.7.r11.7/compiler.31442593_0
# GPU 0: NVIDIA GeForce RTX 4090
# GCC: gcc (Ubuntu 11.3.0-1ubuntu1~22.04.1) 11.3.0
# PyTorch: 1.13.0
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.13.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
# TorchVision: 0.14.0
# OpenCV: 4.7.0
# MMCV: 1.7.1
# MMGen: 0.7.3+ccd1f56
# MMCV Compiler: GCC 9.3
# MMCV CUDA Compiler: 11.7
# ------------------------------------------------------------
#
# 2023-06-09 23:52:02,629 - mmgen - INFO - Distributed training: False
# 2023-06-09 23:52:02,918 - mmgen - INFO - Config:
# _domain_a = None
# _domain_b = None
# model = dict(
#     type='CycleGAN',
#     generator=dict(
#         type='ResnetGenerator',
#         in_channels=3,
#         out_channels=3,
#         base_channels=64,
#         norm_cfg=dict(type='IN'),
#         use_dropout=False,
#         num_blocks=9,
#         padding_mode='reflect',
#         init_cfg=dict(type='normal', gain=0.02)),
#     discriminator=dict(
#         type='PatchDiscriminator',
#         in_channels=3,
#         base_channels=64,
#         num_conv=3,
#         norm_cfg=dict(type='IN'),
#         init_cfg=dict(type='normal', gain=0.02)),
#     gan_loss=dict(
#         type='GANLoss',
#         gan_type='lsgan',
#         real_label_val=1.0,
#         fake_label_val=0.0,
#         loss_weight=1.0),
#     default_domain='bdd100k',
#     reachable_domains=['city', 'bdd100k'],
#     related_domains=['city', 'bdd100k'],
#     gen_auxiliary_loss=[
#         dict(
#             type='L1Loss',
#             loss_weight=10.0,
#             loss_name='cycle_loss',
#             data_info=dict(pred='cycle_city', target='real_city'),
#             reduction='mean'),
#         dict(
#             type='L1Loss',
#             loss_weight=10.0,
#             loss_name='cycle_loss',
#             data_info=dict(pred='cycle_bdd100k', target='real_bdd100k'),
#             reduction='mean'),
#         dict(
#             type='L1Loss',
#             loss_weight=0.5,
#             loss_name='id_loss',
#             data_info=dict(pred='identity_city', target='real_city'),
#             reduction='mean'),
#         dict(
#             type='L1Loss',
#             loss_weight=0.5,
#             loss_name='id_loss',
#             data_info=dict(pred='identity_bdd100k', target='real_bdd100k'),
#             reduction='mean')
#     ])
# train_cfg = dict(buffer_size=50)
# test_cfg = None
# train_dataset_type = 'UnpairedImageDataset'
# val_dataset_type = 'UnpairedImageDataset'
# img_norm_cfg = dict(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
# domain_a = 'city'
# domain_b = 'bdd100k'
# train_pipeline = [
#     dict(
#         type='LoadImageFromFile',
#         io_backend='disk',
#         key='img_city',
#         flag='color'),
#     dict(
#         type='LoadImageFromFile',
#         io_backend='disk',
#         key='img_bdd100k',
#         flag='color'),
#     dict(
#         type='Resize',
#         keys=['img_city', 'img_bdd100k'],
#         scale=(572, 572),
#         interpolation='bicubic'),
#     dict(
#         type='Crop',
#         keys=['img_city', 'img_bdd100k'],
#         crop_size=(512, 512),
#         random_crop=True),
#     dict(type='Flip', keys=['img_city'], direction='horizontal'),
#     dict(type='Flip', keys=['img_bdd100k'], direction='horizontal'),
#     dict(type='RescaleToZeroOne', keys=['img_city', 'img_bdd100k']),
#     dict(
#         type='Normalize',
#         keys=['img_city', 'img_bdd100k'],
#         to_rgb=False,
#         mean=[0.5, 0.5, 0.5],
#         std=[0.5, 0.5, 0.5]),
#     dict(type='ImageToTensor', keys=['img_city', 'img_bdd100k']),
#     dict(
#         type='Collect',
#         keys=['img_city', 'img_bdd100k'],
#         meta_keys=['img_city_path', 'img_bdd100k_path'])
# ]
# test_pipeline = [
#     dict(
#         type='LoadImageFromFile',
#         io_backend='disk',
#         key='img_city',
#         flag='color'),
#     dict(
#         type='LoadImageFromFile',
#         io_backend='disk',
#         key='img_bdd100k',
#         flag='color'),
#     dict(type='RescaleToZeroOne', keys=['img_city', 'img_bdd100k']),
#     dict(
#         type='Normalize',
#         keys=['img_city', 'img_bdd100k'],
#         to_rgb=False,
#         mean=[0.5, 0.5, 0.5],
#         std=[0.5, 0.5, 0.5]),
#     dict(type='ImageToTensor', keys=['img_city', 'img_bdd100k']),
#     dict(
#         type='Collect',
#         keys=['img_city', 'img_bdd100k'],
#         meta_keys=['img_city_path', 'img_bdd100k_path'])
# ]
# data_root = None
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=4,
#     drop_last=True,
#     train=dict(
#         type='UnpairedImageDataset',
#         dataroot=
#         '/home/xiaoguo/anaconda3/envs/mmgen/mmgeneration/data/city2bdd',
#         pipeline=[
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_city',
#                 flag='color'),
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_bdd100k',
#                 flag='color'),
#             dict(
#                 type='Resize',
#                 keys=['img_city', 'img_bdd100k'],
#                 scale=(572, 572),
#                 interpolation='bicubic'),
#             dict(
#                 type='Crop',
#                 keys=['img_city', 'img_bdd100k'],
#                 crop_size=(512, 512),
#                 random_crop=True),
#             dict(type='Flip', keys=['img_city'], direction='horizontal'),
#             dict(type='Flip', keys=['img_bdd100k'], direction='horizontal'),
#             dict(type='RescaleToZeroOne', keys=['img_city', 'img_bdd100k']),
#             dict(
#                 type='Normalize',
#                 keys=['img_city', 'img_bdd100k'],
#                 to_rgb=False,
#                 mean=[0.5, 0.5, 0.5],
#                 std=[0.5, 0.5, 0.5]),
#             dict(type='ImageToTensor', keys=['img_city', 'img_bdd100k']),
#             dict(
#                 type='Collect',
#                 keys=['img_city', 'img_bdd100k'],
#                 meta_keys=['img_city_path', 'img_bdd100k_path'])
#         ],
#         test_mode=False,
#         domain_a='city',
#         domain_b='bdd100k'),
#     val=dict(
#         type='UnpairedImageDataset',
#         dataroot=
#         '/home/xiaoguo/anaconda3/envs/mmgen/mmgeneration/data/city2bdd',
#         pipeline=[
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_city',
#                 flag='color'),
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_bdd100k',
#                 flag='color'),
#             dict(type='RescaleToZeroOne', keys=['img_city', 'img_bdd100k']),
#             dict(
#                 type='Normalize',
#                 keys=['img_city', 'img_bdd100k'],
#                 to_rgb=False,
#                 mean=[0.5, 0.5, 0.5],
#                 std=[0.5, 0.5, 0.5]),
#             dict(type='ImageToTensor', keys=['img_city', 'img_bdd100k']),
#             dict(
#                 type='Collect',
#                 keys=['img_city', 'img_bdd100k'],
#                 meta_keys=['img_city_path', 'img_bdd100k_path'])
#         ],
#         test_mode=True,
#         domain_a='city',
#         domain_b='bdd100k'),
#     test=dict(
#         type='UnpairedImageDataset',
#         dataroot=
#         '/home/xiaoguo/anaconda3/envs/mmgen/mmgeneration/data/city2bdd',
#         pipeline=[
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_city',
#                 flag='color'),
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_bdd100k',
#                 flag='color'),
#             dict(type='RescaleToZeroOne', keys=['img_city', 'img_bdd100k']),
#             dict(
#                 type='Normalize',
#                 keys=['img_city', 'img_bdd100k'],
#                 to_rgb=False,
#                 mean=[0.5, 0.5, 0.5],
#                 std=[0.5, 0.5, 0.5]),
#             dict(type='ImageToTensor', keys=['img_city', 'img_bdd100k']),
#             dict(
#                 type='Collect',
#                 keys=['img_city', 'img_bdd100k'],
#                 meta_keys=['img_city_path', 'img_bdd100k_path'])
#         ],
#         test_mode=True,
#         domain_a='city',
#         domain_b='bdd100k'))
# checkpoint_config = dict(interval=10000, by_epoch=False, save_optimizer=True)
# log_config = dict(interval=100, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [
#     dict(
#         type='MMGenVisualizationHook',
#         output_dir='training_samples',
#         res_name_list=['fake_city', 'fake_bdd100k'],
#         interval=2500)
# ]
# runner = None
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# find_unused_parameters = True
# cudnn_benchmark = True
# opencv_num_threads = 0
# mp_start_method = 'fork'
# dataroot = '/home/xiaoguo/anaconda3/envs/mmgen/mmgeneration/data/city2bdd'
# optimizer = dict(
#     generators=dict(type='Adam', lr=0.0002, betas=(0.5, 0.999)),
#     discriminators=dict(type='Adam', lr=0.0002, betas=(0.5, 0.999)))
# total_iters = 80000
# lr_config = dict(
#     policy='Linear', by_epoch=False, target_lr=0, start=40000, interval=400)
# use_ddp_wrapper = True
# exp_name = 'cyclegan_city2bdd'
# work_dir = 'work_dirs/experiments/cyclegan_city2bdd2/'
# num_images = 106
# metrics = dict(
#     FID=dict(type='FID', num_images=106, image_shape=(3, 512, 512)),
#     IS=dict(
#         type='IS',
#         num_images=106,
#         image_shape=(3, 512, 512),
#         inception_args=dict(type='pytorch')))
# evaluation = dict(
#     type='TranslationEvalHook',
#     target_domain='bdd100k',
#     interval=1000,
#     metrics=[
#         dict(type='FID', num_images=106, bgr2rgb=True),
#         dict(type='IS', num_images=106, inception_args=dict(type='pytorch'))
#     ],
#     best_metric=['fid', 'is'])
# gpu_ids = [0]
#
# 2023-06-09 23:52:02,918 - mmgen - INFO - Set random seed to 2021, deterministic: False, use_rank_shift: False
# /home/xiaoguo/anaconda3/envs/mmgen/lib/python3.8/site-packages/mmcv/cnn/bricks/conv_module.py:153: UserWarning: Unnecessary conv bias before batch/instance norm
#   warnings.warn(
# /home/xiaoguo/anaconda3/envs/mmgen/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/xiaoguo/anaconda3/envs/mmgen/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/xiaoguo/anaconda3/envs/mmgen/lib/python3.8/site-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# 2023-06-09 23:52:03,927 - mmgen - INFO - FID: Adopt Inception in pytorch style
# 2023-06-09 23:52:03,927 - mmgen - INFO - Loading Inception V3 for IS...
# /home/xiaoguo/anaconda3/envs/mmgen/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 2023-06-09 23:52:04,035 - mmgen - INFO - Load Inception V3 Network from Pytorch Model Zoo for IS calculation. The results can only used for monitoring purposes. To get more accuracy IS, please use Tero's Inception V3 checkpoints and use Bicubic Interpolation with Pillow backend for image resizing. More details may refer to https://github.com/open-mmlab/mmgeneration/blob/master/docs/en/quick_run.md#is.
# 2023-06-09 23:52:04,049 - mmgen - INFO - Start running, host: xiaoguo@xiaoguo-System-Product-Name, work_dir: /home/xiaoguo/anaconda3/envs/mmgen/mmgeneration/work_dirs/experiments/cyclegan_city2bdd2
# 2023-06-09 23:52:04,049 - mmgen - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) LinearLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) TranslationEvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) LinearLrUpdaterHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) LinearLrUpdaterHook
# (LOW         ) IterTimerHook
#  --------------------
# after_train_iter:
# (NORMAL      ) CheckpointHook
# (NORMAL      ) VisualizationHook
# (LOW         ) IterTimerHook
# (LOW         ) TranslationEvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2023-06-09 23:52:04,049 - mmgen - INFO - workflow: [('train', 1)], max: 80000 iters
# 2023-06-09 23:52:04,049 - mmgen - INFO - Checkpoints will be saved to work_dirs/experiments/cyclegan_city2bdd2/ckpt/cyclegan_city2bdd2 by HardDiskBackend.
# 2023-06-09 23:53:07,034 - mmgen - INFO - Iter [100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:58:09, time: 0.629, data_time: 0.007, memory: 18046, loss_gan_d_city: 0.5791, loss_gan_d_bdd100k: 0.6117, loss_gan_g_city: 0.9246, loss_gan_g_bdd100k: 0.8938, cycle_loss: 5.8165, id_loss: 0.3968, loss: 8.0317
# 2023-06-09 23:54:07,941 - mmgen - INFO - Iter [200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:43:39, time: 0.609, data_time: 0.002, memory: 18077, loss_gan_d_city: 0.2600, loss_gan_d_bdd100k: 0.2741, loss_gan_g_city: 0.3451, loss_gan_g_bdd100k: 0.3784, cycle_loss: 4.2023, id_loss: 0.3195, loss: 5.2453
# 2023-06-09 23:55:08,676 - mmgen - INFO - Iter [300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:37:20, time: 0.607, data_time: 0.002, memory: 18090, loss_gan_d_city: 0.2542, loss_gan_d_bdd100k: 0.2391, loss_gan_g_city: 0.3897, loss_gan_g_bdd100k: 0.3829, cycle_loss: 3.7925, id_loss: 0.2959, loss: 4.8610
# 2023-06-09 23:56:09,391 - mmgen - INFO - Iter [400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:33:36, time: 0.607, data_time: 0.002, memory: 18095, loss_gan_d_city: 0.2093, loss_gan_d_bdd100k: 0.2423, loss_gan_g_city: 0.4342, loss_gan_g_bdd100k: 0.4144, cycle_loss: 3.6404, id_loss: 0.3153, loss: 4.8044
# 2023-06-09 23:57:09,698 - mmgen - INFO - Iter [500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:29:52, time: 0.603, data_time: 0.002, memory: 18100, loss_gan_d_city: 0.2237, loss_gan_d_bdd100k: 0.2495, loss_gan_g_city: 0.4622, loss_gan_g_bdd100k: 0.4114, cycle_loss: 3.1914, id_loss: 0.2630, loss: 4.3280
# 2023-06-09 23:58:10,083 - mmgen - INFO - Iter [600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:27:14, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.2011, loss_gan_d_bdd100k: 0.2448, loss_gan_g_city: 0.4573, loss_gan_g_bdd100k: 0.3969, cycle_loss: 3.2789, id_loss: 0.2791, loss: 4.4123
# 2023-06-09 23:59:10,378 - mmgen - INFO - Iter [700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:24:53, time: 0.603, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1945, loss_gan_d_bdd100k: 0.2409, loss_gan_g_city: 0.4583, loss_gan_g_bdd100k: 0.4224, cycle_loss: 3.2914, id_loss: 0.2811, loss: 4.4532
# 2023-06-10 00:00:10,761 - mmgen - INFO - Iter [800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:23:01, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.2033, loss_gan_d_bdd100k: 0.2263, loss_gan_g_city: 0.5191, loss_gan_g_bdd100k: 0.4204, cycle_loss: 3.1296, id_loss: 0.2636, loss: 4.3326
# 2023-06-10 00:01:11,226 - mmgen - INFO - Iter [900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:21:27, time: 0.605, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1864, loss_gan_d_bdd100k: 0.2289, loss_gan_g_city: 0.5083, loss_gan_g_bdd100k: 0.4124, cycle_loss: 3.1107, id_loss: 0.2399, loss: 4.2713
# 2023-06-10 00:02:11,587 - mmgen - INFO - Feed reals to FID metric.
# 2023-06-10 00:02:16,100 - mmgen - INFO - Sample 106 fake images for evaluation
# [                                                  ] 0/106, elapsed: 0s, ETA:2023-06-10 00:02:18,223 - mmgen - INFO - `use_pil_resize` is set as True, apply Bicubic interpolation with Pillow backend. We perform type conversion between torch.tensor and PIL.Image in this function and make this process a little bit slow.
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 106/106, 4.7 task/s, elapsed: 23s, ETA:     0s
# 2023-06-10 00:03:42,537 - mmgen - INFO - Now best checkpoint is saved as best_fid_iter_1000.pth.
# 2023-06-10 00:03:42,537 - mmgen - INFO - Best fid is 199.3511 at iter_1000.
# 2023-06-10 00:03:42,851 - mmgen - INFO - Now best checkpoint is saved as best_is_iter_1000.pth.
# 2023-06-10 00:03:42,851 - mmgen - INFO - Best is is 2.4116 at iter_1000.
# 2023-06-10 00:03:42,858 - mmgen - INFO - Exp name: cyclegan_lsgan_resnet_in_facades_b1x1_80k_city2bdd2.py
# 2023-06-10 00:03:42,858 - mmgen - INFO - Iter(val) [1000]	fid: 199.3511, fid_mean: 60.821136474609375, fid_cov: 138.5299, is: 2.4116175174713135, is_std: 0.38780760765075684
# 2023-06-10 00:04:43,323 - mmgen - INFO - Iter [1100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:55:28, time: 1.517, data_time: 0.915, memory: 18108, loss_gan_d_city: 0.1937, loss_gan_d_bdd100k: 0.2294, loss_gan_g_city: 0.4706, loss_gan_g_bdd100k: 0.4187, cycle_loss: 2.6940, id_loss: 0.2250, loss: 3.8084
# 2023-06-10 00:05:43,712 - mmgen - INFO - Iter [1200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:50:58, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1814, loss_gan_d_bdd100k: 0.2362, loss_gan_g_city: 0.4763, loss_gan_g_bdd100k: 0.3984, cycle_loss: 2.7173, id_loss: 0.2109, loss: 3.8029
# 2023-06-10 00:06:44,172 - mmgen - INFO - Iter [1300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:47:05, time: 0.605, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1743, loss_gan_d_bdd100k: 0.2374, loss_gan_g_city: 0.5658, loss_gan_g_bdd100k: 0.3984, cycle_loss: 3.0600, id_loss: 0.2291, loss: 4.2534
# 2023-06-10 00:07:44,541 - mmgen - INFO - Iter [1400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:43:31, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1484, loss_gan_d_bdd100k: 0.2271, loss_gan_g_city: 0.5830, loss_gan_g_bdd100k: 0.4183, cycle_loss: 3.1604, id_loss: 0.2414, loss: 4.4032
# 2023-06-10 00:08:47,477 - mmgen - INFO - Iter [1500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:42:32, time: 0.629, data_time: 0.028, memory: 18108, loss_gan_d_city: 0.1472, loss_gan_d_bdd100k: 0.2357, loss_gan_g_city: 0.5604, loss_gan_g_bdd100k: 0.3922, cycle_loss: 2.8696, id_loss: 0.1966, loss: 4.0188
# 2023-06-10 00:09:47,871 - mmgen - INFO - Iter [1600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:39:27, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1654, loss_gan_d_bdd100k: 0.2287, loss_gan_g_city: 0.5351, loss_gan_g_bdd100k: 0.4474, cycle_loss: 2.6707, id_loss: 0.1858, loss: 3.8390
# 2023-06-10 00:10:48,495 - mmgen - INFO - Iter [1700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:36:48, time: 0.606, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1780, loss_gan_d_bdd100k: 0.2094, loss_gan_g_city: 0.5335, loss_gan_g_bdd100k: 0.4359, cycle_loss: 2.9099, id_loss: 0.2152, loss: 4.0946
# 2023-06-10 00:11:49,033 - mmgen - INFO - Iter [1800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:34:17, time: 0.605, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1474, loss_gan_d_bdd100k: 0.2133, loss_gan_g_city: 0.5783, loss_gan_g_bdd100k: 0.4408, cycle_loss: 3.1730, id_loss: 0.2195, loss: 4.4115
# 2023-06-10 00:12:49,454 - mmgen - INFO - Iter [1900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:31:50, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1700, loss_gan_d_bdd100k: 0.2238, loss_gan_g_city: 0.6380, loss_gan_g_bdd100k: 0.4668, cycle_loss: 3.5211, id_loss: 0.2184, loss: 4.8442
# 2023-06-10 00:13:49,903 - mmgen - INFO - Sample 106 fake images for evaluation
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 106/106, 4.9 task/s, elapsed: 21s, ETA:     0s
# 2023-06-10 00:15:14,886 - mmgen - INFO - Now best checkpoint is saved as best_fid_iter_2000.pth.
# 2023-06-10 00:15:14,886 - mmgen - INFO - Best fid is 199.1350 at iter_2000.
# 2023-06-10 00:15:15,194 - mmgen - INFO - Now best checkpoint is saved as best_is_iter_2000.pth.
# 2023-06-10 00:15:15,194 - mmgen - INFO - Best is is 2.5542 at iter_2000.
# 2023-06-10 00:15:15,200 - mmgen - INFO - Exp name: cyclegan_lsgan_resnet_in_facades_b1x1_80k_city2bdd2.py
# 2023-06-10 00:15:15,200 - mmgen - INFO - Iter(val) [2000]	fid: 199.1350, fid_mean: 57.66545104980469, fid_cov: 141.4696, is: 2.554194211959839, is_std: 0.2721407413482666
# 2023-06-10 00:16:15,595 - mmgen - INFO - Iter [2100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:42:42, time: 1.457, data_time: 0.855, memory: 18108, loss_gan_d_city: 0.1570, loss_gan_d_bdd100k: 0.2048, loss_gan_g_city: 0.5538, loss_gan_g_bdd100k: 0.4772, cycle_loss: 3.5160, id_loss: 0.1947, loss: 4.7417
# 2023-06-10 00:17:15,991 - mmgen - INFO - Iter [2200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:39:54, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1717, loss_gan_d_bdd100k: 0.2034, loss_gan_g_city: 0.5101, loss_gan_g_bdd100k: 0.4974, cycle_loss: 2.8294, id_loss: 0.1692, loss: 4.0060
# 2023-06-10 00:18:16,451 - mmgen - INFO - Iter [2300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:37:17, time: 0.605, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1569, loss_gan_d_bdd100k: 0.1937, loss_gan_g_city: 0.5193, loss_gan_g_bdd100k: 0.4973, cycle_loss: 2.7122, id_loss: 0.1670, loss: 3.8957
# 2023-06-10 00:19:16,888 - mmgen - INFO - Iter [2400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:34:47, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1634, loss_gan_d_bdd100k: 0.1878, loss_gan_g_city: 0.5269, loss_gan_g_bdd100k: 0.5312, cycle_loss: 3.1300, id_loss: 0.1746, loss: 4.3627
# 2023-06-10 00:20:17,464 - mmgen - INFO - Iter [2500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:32:29, time: 0.606, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1692, loss_gan_d_bdd100k: 0.1830, loss_gan_g_city: 0.5356, loss_gan_g_bdd100k: 0.5477, cycle_loss: 2.9847, id_loss: 0.1668, loss: 4.2347
# 2023-06-10 00:21:17,816 - mmgen - INFO - Iter [2600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:30:10, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.2013, loss_gan_d_bdd100k: 0.2003, loss_gan_g_city: 0.5425, loss_gan_g_bdd100k: 0.5047, cycle_loss: 2.6434, id_loss: 0.1542, loss: 3.8448
# 2023-06-10 00:22:18,178 - mmgen - INFO - Iter [2700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:27:58, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1641, loss_gan_d_bdd100k: 0.1727, loss_gan_g_city: 0.4935, loss_gan_g_bdd100k: 0.5164, cycle_loss: 2.5702, id_loss: 0.1557, loss: 3.7359
# 2023-06-10 00:23:18,541 - mmgen - INFO - Iter [2800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:25:50, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1309, loss_gan_d_bdd100k: 0.1809, loss_gan_g_city: 0.6949, loss_gan_g_bdd100k: 0.5931, cycle_loss: 3.2910, id_loss: 0.1723, loss: 4.7513
# 2023-06-10 00:24:18,938 - mmgen - INFO - Iter [2900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:23:48, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1341, loss_gan_d_bdd100k: 0.1652, loss_gan_g_city: 0.5871, loss_gan_g_bdd100k: 0.5771, cycle_loss: 2.8751, id_loss: 0.1672, loss: 4.2065
# 2023-06-10 00:25:21,860 - mmgen - INFO - Sample 106 fake images for evaluation
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 106/106, 4.9 task/s, elapsed: 22s, ETA:     0s
# 2023-06-10 00:26:46,773 - mmgen - INFO - Now best checkpoint is saved as best_fid_iter_3000.pth.
# 2023-06-10 00:26:46,773 - mmgen - INFO - Best fid is 183.9504 at iter_3000.
# 2023-06-10 00:26:46,781 - mmgen - INFO - Exp name: cyclegan_lsgan_resnet_in_facades_b1x1_80k_city2bdd2.py
# 2023-06-10 00:26:46,781 - mmgen - INFO - Iter(val) [3000]	fid: 183.9504, fid_mean: 49.75084686279297, fid_cov: 134.1995, is: 2.509268283843994, is_std: 0.3550300896167755
# 2023-06-10 00:27:47,165 - mmgen - INFO - Iter [3100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:30:04, time: 1.453, data_time: 0.851, memory: 18108, loss_gan_d_city: 0.1236, loss_gan_d_bdd100k: 0.1753, loss_gan_g_city: 0.6634, loss_gan_g_bdd100k: 0.5921, cycle_loss: 2.9268, id_loss: 0.1648, loss: 4.3471
# 2023-06-10 00:28:47,573 - mmgen - INFO - Iter [3200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:27:54, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1178, loss_gan_d_bdd100k: 0.1606, loss_gan_g_city: 0.7063, loss_gan_g_bdd100k: 0.5756, cycle_loss: 2.9677, id_loss: 0.1600, loss: 4.4095
# 2023-06-10 00:29:47,984 - mmgen - INFO - Iter [3300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:25:48, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1276, loss_gan_d_bdd100k: 0.1829, loss_gan_g_city: 0.6194, loss_gan_g_bdd100k: 0.5373, cycle_loss: 2.9508, id_loss: 0.1635, loss: 4.2711
# 2023-06-10 00:30:48,461 - mmgen - INFO - Iter [3400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:23:47, time: 0.605, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1358, loss_gan_d_bdd100k: 0.1713, loss_gan_g_city: 0.5745, loss_gan_g_bdd100k: 0.5288, cycle_loss: 2.8469, id_loss: 0.1693, loss: 4.1196
# 2023-06-10 00:31:48,871 - mmgen - INFO - Iter [3500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:21:48, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1350, loss_gan_d_bdd100k: 0.1552, loss_gan_g_city: 0.6214, loss_gan_g_bdd100k: 0.5631, cycle_loss: 2.6693, id_loss: 0.1506, loss: 4.0043
# 2023-06-10 00:32:49,283 - mmgen - INFO - Iter [3600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:19:53, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1476, loss_gan_d_bdd100k: 0.1729, loss_gan_g_city: 0.5811, loss_gan_g_bdd100k: 0.5441, cycle_loss: 2.6953, id_loss: 0.1522, loss: 3.9727
# 2023-06-10 00:33:49,677 - mmgen - INFO - Iter [3700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:18:00, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1595, loss_gan_d_bdd100k: 0.1789, loss_gan_g_city: 0.5518, loss_gan_g_bdd100k: 0.5147, cycle_loss: 2.7862, id_loss: 0.1525, loss: 4.0052
# 2023-06-10 00:34:50,019 - mmgen - INFO - Iter [3800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:16:09, time: 0.603, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1324, loss_gan_d_bdd100k: 0.1853, loss_gan_g_city: 0.6265, loss_gan_g_bdd100k: 0.5509, cycle_loss: 2.8119, id_loss: 0.1601, loss: 4.1494
# 2023-06-10 00:35:50,456 - mmgen - INFO - Iter [3900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:14:22, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1450, loss_gan_d_bdd100k: 0.1722, loss_gan_g_city: 0.5858, loss_gan_g_bdd100k: 0.5053, cycle_loss: 2.6083, id_loss: 0.1536, loss: 3.8530
# 2023-06-10 00:36:50,845 - mmgen - INFO - Sample 106 fake images for evaluation
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 106/106, 4.9 task/s, elapsed: 22s, ETA:     0s
# 2023-06-10 00:38:15,690 - mmgen - INFO - Now best checkpoint is saved as best_fid_iter_4000.pth.
# 2023-06-10 00:38:15,690 - mmgen - INFO - Best fid is 166.9798 at iter_4000.
# 2023-06-10 00:38:15,698 - mmgen - INFO - Exp name: cyclegan_lsgan_resnet_in_facades_b1x1_80k_city2bdd2.py
# 2023-06-10 00:38:15,698 - mmgen - INFO - Iter(val) [4000]	fid: 166.9798, fid_mean: 39.069828033447266, fid_cov: 127.9100, is: 2.484463930130005, is_std: 0.35156795382499695
# 2023-06-10 00:39:16,096 - mmgen - INFO - Iter [4100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:18:27, time: 1.453, data_time: 0.850, memory: 18108, loss_gan_d_city: 0.1418, loss_gan_d_bdd100k: 0.1642, loss_gan_g_city: 0.5886, loss_gan_g_bdd100k: 0.5361, cycle_loss: 2.6505, id_loss: 0.1501, loss: 3.9252
# 2023-06-10 00:40:16,568 - mmgen - INFO - Iter [4200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:16:36, time: 0.605, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1280, loss_gan_d_bdd100k: 0.1615, loss_gan_g_city: 0.7209, loss_gan_g_bdd100k: 0.5583, cycle_loss: 3.0722, id_loss: 0.1731, loss: 4.5246
# 2023-06-10 00:41:17,105 - mmgen - INFO - Iter [4300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:14:49, time: 0.605, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1139, loss_gan_d_bdd100k: 0.1717, loss_gan_g_city: 0.6585, loss_gan_g_bdd100k: 0.5003, cycle_loss: 2.8894, id_loss: 0.1633, loss: 4.2114
# 2023-06-10 00:42:17,538 - mmgen - INFO - Iter [4400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:13:02, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1327, loss_gan_d_bdd100k: 0.1754, loss_gan_g_city: 0.6044, loss_gan_g_bdd100k: 0.5025, cycle_loss: 2.6679, id_loss: 0.1623, loss: 3.9371
# 2023-06-10 00:43:20,594 - mmgen - INFO - Iter [4500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:12:01, time: 0.631, data_time: 0.028, memory: 18108, loss_gan_d_city: 0.1406, loss_gan_d_bdd100k: 0.1666, loss_gan_g_city: 0.5931, loss_gan_g_bdd100k: 0.5427, cycle_loss: 2.3864, id_loss: 0.1493, loss: 3.6715
# 2023-06-10 00:44:21,007 - mmgen - INFO - Iter [4600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:10:16, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1551, loss_gan_d_bdd100k: 0.1633, loss_gan_g_city: 0.6074, loss_gan_g_bdd100k: 0.5310, cycle_loss: 2.4760, id_loss: 0.1509, loss: 3.7652
# 2023-06-10 00:45:21,439 - mmgen - INFO - Iter [4700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:08:34, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1525, loss_gan_d_bdd100k: 0.1818, loss_gan_g_city: 0.5261, loss_gan_g_bdd100k: 0.5037, cycle_loss: 2.5184, id_loss: 0.1558, loss: 3.7040
# 2023-06-10 00:46:21,876 - mmgen - INFO - Iter [4800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:06:54, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1413, loss_gan_d_bdd100k: 0.1702, loss_gan_g_city: 0.5657, loss_gan_g_bdd100k: 0.5033, cycle_loss: 2.5982, id_loss: 0.1514, loss: 3.8186
# 2023-06-10 00:47:22,350 - mmgen - INFO - Iter [4900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:05:15, time: 0.605, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1469, loss_gan_d_bdd100k: 0.1678, loss_gan_g_city: 0.5468, loss_gan_g_bdd100k: 0.4829, cycle_loss: 2.4618, id_loss: 0.1582, loss: 3.6497
# 2023-06-10 00:48:22,898 - mmgen - INFO - Sample 106 fake images for evaluation
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 106/106, 4.9 task/s, elapsed: 21s, ETA:     0s
# 2023-06-10 00:49:47,673 - mmgen - INFO - Now best checkpoint is saved as best_fid_iter_5000.pth.
# 2023-06-10 00:49:47,673 - mmgen - INFO - Best fid is 152.5670 at iter_5000.
# 2023-06-10 00:49:47,681 - mmgen - INFO - Exp name: cyclegan_lsgan_resnet_in_facades_b1x1_80k_city2bdd2.py
# 2023-06-10 00:49:47,681 - mmgen - INFO - Iter(val) [5000]	fid: 152.5670, fid_mean: 31.945005416870117, fid_cov: 120.6220, is: 2.116361141204834, is_std: 0.15378467738628387
# 2023-06-10 00:50:48,095 - mmgen - INFO - Iter [5100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:08:00, time: 1.452, data_time: 0.850, memory: 18108, loss_gan_d_city: 0.1490, loss_gan_d_bdd100k: 0.1384, loss_gan_g_city: 0.6232, loss_gan_g_bdd100k: 0.5508, cycle_loss: 2.4789, id_loss: 0.1545, loss: 3.8074
# 2023-06-10 00:51:48,467 - mmgen - INFO - Iter [5200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:06:17, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1522, loss_gan_d_bdd100k: 0.1671, loss_gan_g_city: 0.5391, loss_gan_g_bdd100k: 0.4968, cycle_loss: 2.5329, id_loss: 0.1477, loss: 3.7165
# 2023-06-10 00:52:48,907 - mmgen - INFO - Iter [5300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:04:37, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1244, loss_gan_d_bdd100k: 0.1682, loss_gan_g_city: 0.6331, loss_gan_g_bdd100k: 0.5066, cycle_loss: 2.5492, id_loss: 0.1495, loss: 3.8383
# 2023-06-10 00:53:49,333 - mmgen - INFO - Iter [5400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:02:58, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1637, loss_gan_d_bdd100k: 0.1749, loss_gan_g_city: 0.5609, loss_gan_g_bdd100k: 0.5056, cycle_loss: 2.4082, id_loss: 0.1428, loss: 3.6175
# 2023-06-10 00:54:49,782 - mmgen - INFO - Iter [5500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 13:01:21, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1425, loss_gan_d_bdd100k: 0.1836, loss_gan_g_city: 0.5702, loss_gan_g_bdd100k: 0.4830, cycle_loss: 2.4723, id_loss: 0.1534, loss: 3.6790
# 2023-06-10 00:55:50,245 - mmgen - INFO - Iter [5600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:59:45, time: 0.605, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1478, loss_gan_d_bdd100k: 0.1686, loss_gan_g_city: 0.5696, loss_gan_g_bdd100k: 0.4866, cycle_loss: 2.3207, id_loss: 0.1429, loss: 3.5199
# 2023-06-10 00:56:50,710 - mmgen - INFO - Iter [5700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:58:11, time: 0.605, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1520, loss_gan_d_bdd100k: 0.1682, loss_gan_g_city: 0.5472, loss_gan_g_bdd100k: 0.4983, cycle_loss: 2.4241, id_loss: 0.1394, loss: 3.6089
# 2023-06-10 00:57:51,288 - mmgen - INFO - Iter [5800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:56:39, time: 0.606, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1533, loss_gan_d_bdd100k: 0.1673, loss_gan_g_city: 0.5525, loss_gan_g_bdd100k: 0.4872, cycle_loss: 2.3246, id_loss: 0.1413, loss: 3.5056
# 2023-06-10 00:58:51,695 - mmgen - INFO - Iter [5900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:55:06, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1714, loss_gan_d_bdd100k: 0.1815, loss_gan_g_city: 0.5282, loss_gan_g_bdd100k: 0.4997, cycle_loss: 2.2893, id_loss: 0.1372, loss: 3.4545
# 2023-06-10 00:59:54,751 - mmgen - INFO - Sample 106 fake images for evaluation
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 106/106, 4.9 task/s, elapsed: 21s, ETA:     0s
# 2023-06-10 01:01:19,677 - mmgen - INFO - Now best checkpoint is saved as best_is_iter_6000.pth.
# 2023-06-10 01:01:19,677 - mmgen - INFO - Best is is 2.6021 at iter_6000.
# 2023-06-10 01:01:19,684 - mmgen - INFO - Exp name: cyclegan_lsgan_resnet_in_facades_b1x1_80k_city2bdd2.py
# 2023-06-10 01:01:19,684 - mmgen - INFO - Iter(val) [6000]	fid: 163.2021, fid_mean: 35.195701599121094, fid_cov: 128.0064, is: 2.602109909057617, is_std: 0.2676232159137726
# 2023-06-10 01:02:20,104 - mmgen - INFO - Iter [6100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:57:01, time: 1.454, data_time: 0.851, memory: 18108, loss_gan_d_city: 0.1502, loss_gan_d_bdd100k: 0.1664, loss_gan_g_city: 0.5451, loss_gan_g_bdd100k: 0.5224, cycle_loss: 2.2280, id_loss: 0.1331, loss: 3.4286
# 2023-06-10 01:03:20,545 - mmgen - INFO - Iter [6200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:55:26, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1751, loss_gan_d_bdd100k: 0.1775, loss_gan_g_city: 0.5247, loss_gan_g_bdd100k: 0.5321, cycle_loss: 2.3631, id_loss: 0.1390, loss: 3.5590
# 2023-06-10 01:04:20,994 - mmgen - INFO - Iter [6300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:53:53, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1634, loss_gan_d_bdd100k: 0.1850, loss_gan_g_city: 0.5604, loss_gan_g_bdd100k: 0.4815, cycle_loss: 2.3088, id_loss: 0.1425, loss: 3.4933
# 2023-06-10 01:05:21,465 - mmgen - INFO - Iter [6400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:52:21, time: 0.605, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1385, loss_gan_d_bdd100k: 0.1696, loss_gan_g_city: 0.6733, loss_gan_g_bdd100k: 0.5362, cycle_loss: 2.6473, id_loss: 0.1471, loss: 4.0040
# 2023-06-10 01:06:21,894 - mmgen - INFO - Iter [6500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:50:49, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1504, loss_gan_d_bdd100k: 0.1734, loss_gan_g_city: 0.5490, loss_gan_g_bdd100k: 0.5025, cycle_loss: 2.1716, id_loss: 0.1312, loss: 3.3543
# 2023-06-10 01:07:22,277 - mmgen - INFO - Iter [6600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:49:18, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1496, loss_gan_d_bdd100k: 0.1698, loss_gan_g_city: 0.5289, loss_gan_g_bdd100k: 0.5208, cycle_loss: 2.2031, id_loss: 0.1362, loss: 3.3890
# 2023-06-10 01:08:22,682 - mmgen - INFO - Iter [6700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:47:48, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1564, loss_gan_d_bdd100k: 0.1848, loss_gan_g_city: 0.5846, loss_gan_g_bdd100k: 0.5208, cycle_loss: 2.4963, id_loss: 0.1366, loss: 3.7383
# 2023-06-10 01:09:23,138 - mmgen - INFO - Iter [6800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:46:19, time: 0.605, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1451, loss_gan_d_bdd100k: 0.1610, loss_gan_g_city: 0.5484, loss_gan_g_bdd100k: 0.4808, cycle_loss: 2.3426, id_loss: 0.1399, loss: 3.5117
# 2023-06-10 01:10:23,611 - mmgen - INFO - Iter [6900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:44:51, time: 0.605, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1616, loss_gan_d_bdd100k: 0.1733, loss_gan_g_city: 0.5705, loss_gan_g_bdd100k: 0.5111, cycle_loss: 2.2728, id_loss: 0.1319, loss: 3.4864
# 2023-06-10 01:11:24,104 - mmgen - INFO - Sample 106 fake images for evaluation
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 106/106, 5.0 task/s, elapsed: 21s, ETA:     0s
# 2023-06-10 01:12:48,582 - mmgen - INFO - Exp name: cyclegan_lsgan_resnet_in_facades_b1x1_80k_city2bdd2.py
# 2023-06-10 01:12:48,582 - mmgen - INFO - Iter(val) [7000]	fid: 173.1412, fid_mean: 42.92805862426758, fid_cov: 130.2131, is: 2.4766006469726562, is_std: 0.3232307434082031
# 2023-06-10 01:13:48,949 - mmgen - INFO - Iter [7100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:46:04, time: 1.448, data_time: 0.847, memory: 18108, loss_gan_d_city: 0.1707, loss_gan_d_bdd100k: 0.1790, loss_gan_g_city: 0.5383, loss_gan_g_bdd100k: 0.4999, cycle_loss: 2.2314, id_loss: 0.1339, loss: 3.4034
# 2023-06-10 01:14:49,367 - mmgen - INFO - Iter [7200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:44:34, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1657, loss_gan_d_bdd100k: 0.1814, loss_gan_g_city: 0.5281, loss_gan_g_bdd100k: 0.4491, cycle_loss: 2.1990, id_loss: 0.1306, loss: 3.3068
# 2023-06-10 01:15:49,823 - mmgen - INFO - Iter [7300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:43:06, time: 0.605, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1800, loss_gan_d_bdd100k: 0.1932, loss_gan_g_city: 0.5228, loss_gan_g_bdd100k: 0.4483, cycle_loss: 2.2490, id_loss: 0.1386, loss: 3.3586
# 2023-06-10 01:16:50,264 - mmgen - INFO - Iter [7400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:41:38, time: 0.604, data_time: 0.002, memory: 18108, loss_gan_d_city: 0.1667, loss_gan_d_bdd100k: 0.1777, loss_gan_g_city: 0.5161, loss_gan_g_bdd100k: 0.4734, cycle_loss: 2.1263, id_loss: 0.1327, loss: 3.2486
# 2023-06-10 01:17:53,419 - mmgen - INFO - Iter [7500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:40:37, time: 0.632, data_time: 0.027, memory: 18109, loss_gan_d_city: 0.1423, loss_gan_d_bdd100k: 0.1788, loss_gan_g_city: 0.5966, loss_gan_g_bdd100k: 0.4921, cycle_loss: 2.2789, id_loss: 0.1343, loss: 3.5019
# 2023-06-10 01:18:53,804 - mmgen - INFO - Iter [7600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:39:10, time: 0.604, data_time: 0.002, memory: 18109, loss_gan_d_city: 0.1459, loss_gan_d_bdd100k: 0.1915, loss_gan_g_city: 0.5812, loss_gan_g_bdd100k: 0.5210, cycle_loss: 2.4181, id_loss: 0.1320, loss: 3.6523
# 2023-06-10 01:19:54,317 - mmgen - INFO - Iter [7700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:37:44, time: 0.605, data_time: 0.002, memory: 18109, loss_gan_d_city: 0.1405, loss_gan_d_bdd100k: 0.1960, loss_gan_g_city: 0.5817, loss_gan_g_bdd100k: 0.4622, cycle_loss: 2.3359, id_loss: 0.1347, loss: 3.5145
# 2023-06-10 01:20:54,767 - mmgen - INFO - Iter [7800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:36:19, time: 0.604, data_time: 0.002, memory: 18109, loss_gan_d_city: 0.1540, loss_gan_d_bdd100k: 0.1743, loss_gan_g_city: 0.5651, loss_gan_g_bdd100k: 0.4871, cycle_loss: 2.2723, id_loss: 0.1413, loss: 3.4659
# 2023-06-10 01:21:55,197 - mmgen - INFO - Iter [7900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:34:54, time: 0.604, data_time: 0.002, memory: 18110, loss_gan_d_city: 0.1451, loss_gan_d_bdd100k: 0.1756, loss_gan_g_city: 0.5189, loss_gan_g_bdd100k: 0.5486, cycle_loss: 2.2848, id_loss: 0.1342, loss: 3.4865
# 2023-06-10 01:22:55,653 - mmgen - INFO - Sample 106 fake images for evaluation
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 106/106, 4.9 task/s, elapsed: 22s, ETA:     0s
# 2023-06-10 01:24:20,143 - mmgen - INFO - Exp name: cyclegan_lsgan_resnet_in_facades_b1x1_80k_city2bdd2.py
# 2023-06-10 01:24:20,143 - mmgen - INFO - Iter(val) [8000]	fid: 174.0073, fid_mean: 44.774803161621094, fid_cov: 129.2325, is: 2.4972476959228516, is_std: 0.1688947081565857
# 2023-06-10 01:25:20,261 - mmgen - INFO - Iter [8100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:35:36, time: 1.446, data_time: 0.847, memory: 18110, loss_gan_d_city: 0.1684, loss_gan_d_bdd100k: 0.1750, loss_gan_g_city: 0.4895, loss_gan_g_bdd100k: 0.4514, cycle_loss: 2.0996, id_loss: 0.1262, loss: 3.1667
# 2023-06-10 01:26:20,439 - mmgen - INFO - Iter [8200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:34:08, time: 0.602, data_time: 0.002, memory: 18110, loss_gan_d_city: 0.1718, loss_gan_d_bdd100k: 0.1835, loss_gan_g_city: 0.5498, loss_gan_g_bdd100k: 0.4955, cycle_loss: 2.1621, id_loss: 0.1258, loss: 3.3331
# 2023-06-10 01:27:20,602 - mmgen - INFO - Iter [8300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:32:40, time: 0.602, data_time: 0.002, memory: 18110, loss_gan_d_city: 0.1636, loss_gan_d_bdd100k: 0.1801, loss_gan_g_city: 0.5059, loss_gan_g_bdd100k: 0.4645, cycle_loss: 2.1527, id_loss: 0.1304, loss: 3.2534
# 2023-06-10 01:28:20,759 - mmgen - INFO - Iter [8400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:31:13, time: 0.602, data_time: 0.002, memory: 18110, loss_gan_d_city: 0.1553, loss_gan_d_bdd100k: 0.1898, loss_gan_g_city: 0.5745, loss_gan_g_bdd100k: 0.4661, cycle_loss: 2.2540, id_loss: 0.1321, loss: 3.4266
# 2023-06-10 01:29:20,921 - mmgen - INFO - Iter [8500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 12:29:47, time: 0.602, data_time: 0.002, memory: 18110, loss_gan_d_city: 0.1674, loss_gan_d_bdd100k: 0.1855, loss_gan_g_city: 0.5415, loss_gan_g_bdd100k: 0.4731, cycle_loss: 2.2231, id_loss: 0.1373, loss: 3.3749
# ...
# 2023-06-10 14:19:29,592 - mmgen - INFO - Iter [75500/80000]	lr_generators: 2.400e-05 lr_discriminators: 2.400e-05, eta: 0:47:10, time: 0.605, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1826, loss_gan_d_bdd100k: 0.1356, loss_gan_g_city: 0.4287, loss_gan_g_bdd100k: 0.5323, cycle_loss: 0.9806, id_loss: 0.0719, loss: 2.0135
# 2023-06-10 14:20:30,136 - mmgen - INFO - Iter [75600/80000]	lr_generators: 2.400e-05 lr_discriminators: 2.400e-05, eta: 0:46:07, time: 0.605, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1799, loss_gan_d_bdd100k: 0.1418, loss_gan_g_city: 0.4220, loss_gan_g_bdd100k: 0.5273, cycle_loss: 0.9885, id_loss: 0.0739, loss: 2.0117
# 2023-06-10 14:21:30,647 - mmgen - INFO - Iter [75700/80000]	lr_generators: 2.200e-05 lr_discriminators: 2.200e-05, eta: 0:45:04, time: 0.605, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1783, loss_gan_d_bdd100k: 0.1399, loss_gan_g_city: 0.4143, loss_gan_g_bdd100k: 0.5218, cycle_loss: 1.0030, id_loss: 0.0759, loss: 2.0149
# 2023-06-10 14:22:31,161 - mmgen - INFO - Iter [75800/80000]	lr_generators: 2.200e-05 lr_discriminators: 2.200e-05, eta: 0:44:01, time: 0.605, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1868, loss_gan_d_bdd100k: 0.1375, loss_gan_g_city: 0.4184, loss_gan_g_bdd100k: 0.5436, cycle_loss: 1.0006, id_loss: 0.0727, loss: 2.0353
# 2023-06-10 14:23:34,178 - mmgen - INFO - Iter [75900/80000]	lr_generators: 2.200e-05 lr_discriminators: 2.200e-05, eta: 0:42:58, time: 0.630, data_time: 0.027, memory: 18118, loss_gan_d_city: 0.1745, loss_gan_d_bdd100k: 0.1332, loss_gan_g_city: 0.4343, loss_gan_g_bdd100k: 0.5128, cycle_loss: 0.9702, id_loss: 0.0683, loss: 1.9857
# 2023-06-10 14:24:34,636 - mmgen - INFO - Sample 106 fake images for evaluation
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 106/106, 4.9 task/s, elapsed: 21s, ETA:     0s
# 2023-06-10 14:25:59,256 - mmgen - INFO - Exp name: cyclegan_lsgan_resnet_in_facades_b1x1_80k_city2bdd2.py
# 2023-06-10 14:25:59,256 - mmgen - INFO - Iter(val) [76000]	fid: 136.6751, fid_mean: 18.562393188476562, fid_cov: 118.1127, is: 2.7247211933135986, is_std: 0.2501373887062073
# 2023-06-10 14:26:59,404 - mmgen - INFO - Iter [76100/80000]	lr_generators: 2.000e-05 lr_discriminators: 2.000e-05, eta: 0:40:53, time: 1.448, data_time: 0.848, memory: 18118, loss_gan_d_city: 0.1875, loss_gan_d_bdd100k: 0.1365, loss_gan_g_city: 0.4182, loss_gan_g_bdd100k: 0.5274, cycle_loss: 1.0007, id_loss: 0.0736, loss: 2.0199
# 2023-06-10 14:27:59,594 - mmgen - INFO - Iter [76200/80000]	lr_generators: 2.000e-05 lr_discriminators: 2.000e-05, eta: 0:39:50, time: 0.602, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1808, loss_gan_d_bdd100k: 0.1415, loss_gan_g_city: 0.4146, loss_gan_g_bdd100k: 0.5282, cycle_loss: 0.9997, id_loss: 0.0725, loss: 2.0150
# 2023-06-10 14:28:59,773 - mmgen - INFO - Iter [76300/80000]	lr_generators: 2.000e-05 lr_discriminators: 2.000e-05, eta: 0:38:47, time: 0.602, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1784, loss_gan_d_bdd100k: 0.1291, loss_gan_g_city: 0.4194, loss_gan_g_bdd100k: 0.5630, cycle_loss: 0.9881, id_loss: 0.0712, loss: 2.0418
# 2023-06-10 14:29:59,914 - mmgen - INFO - Iter [76400/80000]	lr_generators: 2.000e-05 lr_discriminators: 2.000e-05, eta: 0:37:44, time: 0.601, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1966, loss_gan_d_bdd100k: 0.1396, loss_gan_g_city: 0.3918, loss_gan_g_bdd100k: 0.5190, cycle_loss: 0.9738, id_loss: 0.0723, loss: 1.9568
# 2023-06-10 14:31:00,121 - mmgen - INFO - Iter [76500/80000]	lr_generators: 1.800e-05 lr_discriminators: 1.800e-05, eta: 0:36:41, time: 0.602, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1846, loss_gan_d_bdd100k: 0.1436, loss_gan_g_city: 0.4170, loss_gan_g_bdd100k: 0.5140, cycle_loss: 0.9853, id_loss: 0.0744, loss: 1.9908
# 2023-06-10 14:32:00,240 - mmgen - INFO - Iter [76600/80000]	lr_generators: 1.800e-05 lr_discriminators: 1.800e-05, eta: 0:35:38, time: 0.601, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1802, loss_gan_d_bdd100k: 0.1367, loss_gan_g_city: 0.4158, loss_gan_g_bdd100k: 0.5292, cycle_loss: 0.9756, id_loss: 0.0719, loss: 1.9925
# 2023-06-10 14:33:00,422 - mmgen - INFO - Iter [76700/80000]	lr_generators: 1.800e-05 lr_discriminators: 1.800e-05, eta: 0:34:35, time: 0.602, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1808, loss_gan_d_bdd100k: 0.1451, loss_gan_g_city: 0.4183, loss_gan_g_bdd100k: 0.5194, cycle_loss: 0.9984, id_loss: 0.0743, loss: 2.0104
# 2023-06-10 14:34:00,547 - mmgen - INFO - Iter [76800/80000]	lr_generators: 1.800e-05 lr_discriminators: 1.800e-05, eta: 0:33:32, time: 0.601, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1769, loss_gan_d_bdd100k: 0.1357, loss_gan_g_city: 0.4283, loss_gan_g_bdd100k: 0.5442, cycle_loss: 0.9730, id_loss: 0.0752, loss: 2.0207
# 2023-06-10 14:35:00,660 - mmgen - INFO - Iter [76900/80000]	lr_generators: 1.600e-05 lr_discriminators: 1.600e-05, eta: 0:32:29, time: 0.601, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1867, loss_gan_d_bdd100k: 0.1365, loss_gan_g_city: 0.4120, loss_gan_g_bdd100k: 0.5287, cycle_loss: 0.9820, id_loss: 0.0738, loss: 1.9965
# 2023-06-10 14:36:00,822 - mmgen - INFO - Sample 106 fake images for evaluation
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 106/106, 4.9 task/s, elapsed: 21s, ETA:     0s
# 2023-06-10 14:37:25,302 - mmgen - INFO - Exp name: cyclegan_lsgan_resnet_in_facades_b1x1_80k_city2bdd2.py
# 2023-06-10 14:37:25,302 - mmgen - INFO - Iter(val) [77000]	fid: 138.6761, fid_mean: 19.389118194580078, fid_cov: 119.2870, is: 2.6608595848083496, is_std: 0.2828318178653717
# 2023-06-10 14:38:25,685 - mmgen - INFO - Iter [77100/80000]	lr_generators: 1.600e-05 lr_discriminators: 1.600e-05, eta: 0:30:24, time: 1.449, data_time: 0.847, memory: 18118, loss_gan_d_city: 0.1782, loss_gan_d_bdd100k: 0.1337, loss_gan_g_city: 0.4303, loss_gan_g_bdd100k: 0.5457, cycle_loss: 0.9902, id_loss: 0.0741, loss: 2.0404
# 2023-06-10 14:39:26,110 - mmgen - INFO - Iter [77200/80000]	lr_generators: 1.600e-05 lr_discriminators: 1.600e-05, eta: 0:29:21, time: 0.604, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1831, loss_gan_d_bdd100k: 0.1401, loss_gan_g_city: 0.4248, loss_gan_g_bdd100k: 0.5270, cycle_loss: 0.9707, id_loss: 0.0736, loss: 1.9961
# 2023-06-10 14:40:26,489 - mmgen - INFO - Iter [77300/80000]	lr_generators: 1.400e-05 lr_discriminators: 1.400e-05, eta: 0:28:18, time: 0.604, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1953, loss_gan_d_bdd100k: 0.1334, loss_gan_g_city: 0.3888, loss_gan_g_bdd100k: 0.5350, cycle_loss: 0.9900, id_loss: 0.0722, loss: 1.9859
# 2023-06-10 14:41:29,499 - mmgen - INFO - Iter [77400/80000]	lr_generators: 1.400e-05 lr_discriminators: 1.400e-05, eta: 0:27:15, time: 0.630, data_time: 0.028, memory: 18118, loss_gan_d_city: 0.1776, loss_gan_d_bdd100k: 0.1367, loss_gan_g_city: 0.4191, loss_gan_g_bdd100k: 0.5321, cycle_loss: 0.9524, id_loss: 0.0685, loss: 1.9721
# 2023-06-10 14:42:30,196 - mmgen - INFO - Iter [77500/80000]	lr_generators: 1.400e-05 lr_discriminators: 1.400e-05, eta: 0:26:12, time: 0.607, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1841, loss_gan_d_bdd100k: 0.1286, loss_gan_g_city: 0.4172, loss_gan_g_bdd100k: 0.5554, cycle_loss: 0.9526, id_loss: 0.0728, loss: 1.9980
# 2023-06-10 14:43:30,309 - mmgen - INFO - Iter [77600/80000]	lr_generators: 1.400e-05 lr_discriminators: 1.400e-05, eta: 0:25:09, time: 0.601, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1772, loss_gan_d_bdd100k: 0.1339, loss_gan_g_city: 0.4233, loss_gan_g_bdd100k: 0.5431, cycle_loss: 0.9614, id_loss: 0.0722, loss: 1.9999
# 2023-06-10 14:44:30,480 - mmgen - INFO - Iter [77700/80000]	lr_generators: 1.200e-05 lr_discriminators: 1.200e-05, eta: 0:24:06, time: 0.602, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1854, loss_gan_d_bdd100k: 0.1342, loss_gan_g_city: 0.4091, loss_gan_g_bdd100k: 0.5458, cycle_loss: 0.9863, id_loss: 0.0741, loss: 2.0152
# 2023-06-10 14:45:30,565 - mmgen - INFO - Iter [77800/80000]	lr_generators: 1.200e-05 lr_discriminators: 1.200e-05, eta: 0:23:03, time: 0.601, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1864, loss_gan_d_bdd100k: 0.1320, loss_gan_g_city: 0.4107, loss_gan_g_bdd100k: 0.5382, cycle_loss: 0.9785, id_loss: 0.0704, loss: 1.9978
# 2023-06-10 14:46:30,721 - mmgen - INFO - Iter [77900/80000]	lr_generators: 1.200e-05 lr_discriminators: 1.200e-05, eta: 0:22:00, time: 0.602, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1899, loss_gan_d_bdd100k: 0.1386, loss_gan_g_city: 0.4044, loss_gan_g_bdd100k: 0.5361, cycle_loss: 0.9599, id_loss: 0.0718, loss: 1.9723
# 2023-06-10 14:47:30,870 - mmgen - INFO - Sample 106 fake images for evaluation
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 106/106, 4.9 task/s, elapsed: 22s, ETA:     0s
# 2023-06-10 14:48:55,559 - mmgen - INFO - Exp name: cyclegan_lsgan_resnet_in_facades_b1x1_80k_city2bdd2.py
# 2023-06-10 14:48:55,559 - mmgen - INFO - Iter(val) [78000]	fid: 139.1292, fid_mean: 19.57166290283203, fid_cov: 119.5575, is: 2.707549571990967, is_std: 0.271648645401001
# 2023-06-10 14:49:55,681 - mmgen - INFO - Iter [78100/80000]	lr_generators: 1.000e-05 lr_discriminators: 1.000e-05, eta: 0:19:55, time: 1.448, data_time: 0.849, memory: 18118, loss_gan_d_city: 0.1822, loss_gan_d_bdd100k: 0.1349, loss_gan_g_city: 0.4254, loss_gan_g_bdd100k: 0.5386, cycle_loss: 0.9498, id_loss: 0.0704, loss: 1.9842
# 2023-06-10 14:50:55,893 - mmgen - INFO - Iter [78200/80000]	lr_generators: 1.000e-05 lr_discriminators: 1.000e-05, eta: 0:18:52, time: 0.602, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1839, loss_gan_d_bdd100k: 0.1400, loss_gan_g_city: 0.4092, loss_gan_g_bdd100k: 0.5339, cycle_loss: 0.9685, id_loss: 0.0748, loss: 1.9864
# 2023-06-10 14:51:56,059 - mmgen - INFO - Iter [78300/80000]	lr_generators: 1.000e-05 lr_discriminators: 1.000e-05, eta: 0:17:49, time: 0.602, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1783, loss_gan_d_bdd100k: 0.1308, loss_gan_g_city: 0.4304, loss_gan_g_bdd100k: 0.5433, cycle_loss: 0.9747, id_loss: 0.0729, loss: 2.0214
# 2023-06-10 14:52:56,248 - mmgen - INFO - Iter [78400/80000]	lr_generators: 1.000e-05 lr_discriminators: 1.000e-05, eta: 0:16:46, time: 0.602, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1806, loss_gan_d_bdd100k: 0.1345, loss_gan_g_city: 0.4154, loss_gan_g_bdd100k: 0.5322, cycle_loss: 0.9600, id_loss: 0.0737, loss: 1.9813
# 2023-06-10 14:53:56,451 - mmgen - INFO - Iter [78500/80000]	lr_generators: 8.000e-06 lr_discriminators: 8.000e-06, eta: 0:15:43, time: 0.602, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1826, loss_gan_d_bdd100k: 0.1307, loss_gan_g_city: 0.4126, loss_gan_g_bdd100k: 0.5337, cycle_loss: 0.9742, id_loss: 0.0725, loss: 1.9930
# 2023-06-10 14:54:56,657 - mmgen - INFO - Iter [78600/80000]	lr_generators: 8.000e-06 lr_discriminators: 8.000e-06, eta: 0:14:40, time: 0.602, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1799, loss_gan_d_bdd100k: 0.1324, loss_gan_g_city: 0.4213, loss_gan_g_bdd100k: 0.5449, cycle_loss: 0.9551, id_loss: 0.0722, loss: 1.9934
# 2023-06-10 14:55:56,847 - mmgen - INFO - Iter [78700/80000]	lr_generators: 8.000e-06 lr_discriminators: 8.000e-06, eta: 0:13:37, time: 0.602, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1869, loss_gan_d_bdd100k: 0.1392, loss_gan_g_city: 0.4127, loss_gan_g_bdd100k: 0.5204, cycle_loss: 0.9750, id_loss: 0.0729, loss: 1.9811
# 2023-06-10 14:56:57,056 - mmgen - INFO - Iter [78800/80000]	lr_generators: 8.000e-06 lr_discriminators: 8.000e-06, eta: 0:12:34, time: 0.602, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1820, loss_gan_d_bdd100k: 0.1370, loss_gan_g_city: 0.4235, loss_gan_g_bdd100k: 0.5295, cycle_loss: 0.9747, id_loss: 0.0720, loss: 1.9996
# 2023-06-10 14:57:59,948 - mmgen - INFO - Iter [78900/80000]	lr_generators: 6.000e-06 lr_discriminators: 6.000e-06, eta: 0:11:31, time: 0.629, data_time: 0.027, memory: 18118, loss_gan_d_city: 0.1735, loss_gan_d_bdd100k: 0.1358, loss_gan_g_city: 0.4339, loss_gan_g_bdd100k: 0.5292, cycle_loss: 0.9457, id_loss: 0.0690, loss: 1.9778
# 2023-06-10 14:59:00,271 - mmgen - INFO - Sample 106 fake images for evaluation
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 106/106, 4.9 task/s, elapsed: 21s, ETA:     0s
# 2023-06-10 15:00:24,836 - mmgen - INFO - Exp name: cyclegan_lsgan_resnet_in_facades_b1x1_80k_city2bdd2.py
# 2023-06-10 15:00:24,836 - mmgen - INFO - Iter(val) [79000]	fid: 141.1302, fid_mean: 20.836143493652344, fid_cov: 120.2940, is: 2.730499505996704, is_std: 0.332169771194458
# 2023-06-10 15:01:25,216 - mmgen - INFO - Iter [79100/80000]	lr_generators: 6.000e-06 lr_discriminators: 6.000e-06, eta: 0:09:26, time: 1.449, data_time: 0.848, memory: 18118, loss_gan_d_city: 0.1835, loss_gan_d_bdd100k: 0.1365, loss_gan_g_city: 0.4210, loss_gan_g_bdd100k: 0.5433, cycle_loss: 0.9415, id_loss: 0.0722, loss: 1.9781
# 2023-06-10 15:02:25,658 - mmgen - INFO - Iter [79200/80000]	lr_generators: 6.000e-06 lr_discriminators: 6.000e-06, eta: 0:08:23, time: 0.604, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1813, loss_gan_d_bdd100k: 0.1383, loss_gan_g_city: 0.4148, loss_gan_g_bdd100k: 0.5398, cycle_loss: 0.9774, id_loss: 0.0728, loss: 2.0047
# 2023-06-10 15:03:26,058 - mmgen - INFO - Iter [79300/80000]	lr_generators: 4.000e-06 lr_discriminators: 4.000e-06, eta: 0:07:20, time: 0.604, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1791, loss_gan_d_bdd100k: 0.1311, loss_gan_g_city: 0.4124, loss_gan_g_bdd100k: 0.5425, cycle_loss: 0.9392, id_loss: 0.0683, loss: 1.9624
# 2023-06-10 15:04:26,458 - mmgen - INFO - Iter [79400/80000]	lr_generators: 4.000e-06 lr_discriminators: 4.000e-06, eta: 0:06:17, time: 0.604, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1876, loss_gan_d_bdd100k: 0.1386, loss_gan_g_city: 0.4217, loss_gan_g_bdd100k: 0.5279, cycle_loss: 0.9602, id_loss: 0.0723, loss: 1.9822
# 2023-06-10 15:05:26,844 - mmgen - INFO - Iter [79500/80000]	lr_generators: 4.000e-06 lr_discriminators: 4.000e-06, eta: 0:05:14, time: 0.604, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1788, loss_gan_d_bdd100k: 0.1324, loss_gan_g_city: 0.4179, loss_gan_g_bdd100k: 0.5251, cycle_loss: 0.9330, id_loss: 0.0696, loss: 1.9456
# 2023-06-10 15:06:27,331 - mmgen - INFO - Iter [79600/80000]	lr_generators: 4.000e-06 lr_discriminators: 4.000e-06, eta: 0:04:11, time: 0.605, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1762, loss_gan_d_bdd100k: 0.1350, loss_gan_g_city: 0.4293, loss_gan_g_bdd100k: 0.5369, cycle_loss: 0.9553, id_loss: 0.0703, loss: 1.9919
# 2023-06-10 15:07:27,729 - mmgen - INFO - Iter [79700/80000]	lr_generators: 2.000e-06 lr_discriminators: 2.000e-06, eta: 0:03:08, time: 0.604, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1818, loss_gan_d_bdd100k: 0.1332, loss_gan_g_city: 0.4216, loss_gan_g_bdd100k: 0.5390, cycle_loss: 0.9329, id_loss: 0.0723, loss: 1.9658
# 2023-06-10 15:08:28,145 - mmgen - INFO - Iter [79800/80000]	lr_generators: 2.000e-06 lr_discriminators: 2.000e-06, eta: 0:02:05, time: 0.604, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1822, loss_gan_d_bdd100k: 0.1334, loss_gan_g_city: 0.4303, loss_gan_g_bdd100k: 0.5418, cycle_loss: 0.9711, id_loss: 0.0758, loss: 2.0191
# 2023-06-10 15:09:28,589 - mmgen - INFO - Iter [79900/80000]	lr_generators: 2.000e-06 lr_discriminators: 2.000e-06, eta: 0:01:02, time: 0.604, data_time: 0.002, memory: 18118, loss_gan_d_city: 0.1749, loss_gan_d_bdd100k: 0.1261, loss_gan_g_city: 0.4279, loss_gan_g_bdd100k: 0.5577, cycle_loss: 0.9473, id_loss: 0.0717, loss: 2.0046
# 2023-06-10 15:10:29,071 - mmgen - INFO - Saving checkpoint at 80000 iterations
# 2023-06-10 15:10:29,594 - mmgen - INFO - Sample 106 fake images for evaluation
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 106/106, 4.9 task/s, elapsed: 21s, ETA:     0s
# 2023-06-10 15:11:54,210 - mmgen - INFO - Exp name: cyclegan_lsgan_resnet_in_facades_b1x1_80k_city2bdd2.py
# 2023-06-10 15:11:54,210 - mmgen - INFO - Iter(val) [80000]	fid: 138.9981, fid_mean: 19.685447692871094, fid_cov: 119.3126, is: 2.7150046825408936, is_std: 0.27101126313209534
